# %% [markdown]
# #### Comment pre-processing
#
# For both topic extraction and sentiment analysis modelling, it would be useful to firstly correct the typos, non-regular characters and other abnormal appearances in the raw comment texts.
#
# At this stage, we should keep punctuation, capitalization, information language, misspellings, and emotional expressions. However, we do want to correct things like:
# - character encoding issues: e.g. "wÃ¡s" → "was",  "I don¬"t know much" → "I don't know much"
# - Unicode encoding artifacts
# - Excessive whitespace
# - comments that are literally 'na' or some variation
# - typo fixes
#
# Following this step, we can be sure in the integrity of our text data for further processing adapted to topic modelling/sentiment analysis.
#
# Firstly, we'll apply some function based methods to address the unicode artifacts, character encoding, and na's.
#
# Next, we can rely on an LLM for fixing basic typos, while making sure to check any changed responses. If scaling this approach, a lightweight model would be used, but in our small sample, we can do a many-shot run with a model like local deepseek-r1, checking any changes. Likewise, both topic modelling and sentiment analysis models are often robust to typos (often through the use of embeddings models) so this step might not be necessary. (UPDATED: Step deemed too time-inefficient to do)

# %%
exec(open('../scripts/setup.py').read()) # load our data/packages
# Out:
# Main dataset loaded: (582, 15)

# %%
# randomly print a sample from non-missing LTR_COMMENT in df
sample_size = 70
sample = df[df['LTR_COMMENT'].notna()]['LTR_COMMENT'].sample(n=sample_size, random_state=47).tolist()
for i, comment in enumerate(sample, 1):
    print(f"Sample {i}: {comment}\n")
# Out:
# Sample 1: Very hardworking and punctual quits who carried out the work
#
# Sample 2: I got a good offer with company than sky
#
# Sample 3: Is a good service but trying to get to talk to a human person is really hhard , the people you use do not use very good english therefore were not easy to communicate with
#
# Sample 4: Very polite and informative
#
# Sample 5: Cut my Internet off . Asked for router to be sent after 5.00 tracker shows between 10 and 12
#
# Sample 6: The gentleman who dealt us was so helpful and friendly.. he deserves a lot of credit. Very nice man..
#
# Sample 7: you are very efficient=====will you be moving sat dish when you install
#
# Sample 8: How easy it was to set up.
#
# Sample 9: Very adaptable and patient/ helpful
#
# Sample 10: I've not agreed to any of this yet I'm bombarded with emails that you cannot reply to and setting up direct debits without my knowledge
#
# Sample 11: They are efficient
#
# Sample 12: Extremely disappointed with your customer service team. I am still awaiting a response from your fraud prevention team and I have waste hours of my time already on a service I have yet to receive.
#
# Sample 13: Efficient, courteous staff. Good service and prices. Glad to be on board. John.
#
# Sample 14: Lady was so nice on the phone as I don¬"t know much about Internet
#
# Sample 15: Good customer service very polite &helpful lad didn¬"t over sell anything. The price was good.
#
# Sample 16: they where nice and pleasent aswell
#
# Sample 17: The engineer that attended my house was very friendly with great sense of humour
#
# Sample 18: indian call centres
#
# Sample 19: Daughters organised my means of communication at distance for my return to live to England. They used you. All went smoothly and quickly.
#
# Sample 20: Price of my bundle went up 2 days after i placed the order
#
# Sample 21: Technician was nice
#
# Sample 22: Very helpful
#
# Sample 23: I was offered the best option that suits me, friendly conversation, and helpful.
#
# Sample 24: I was cut off 3 times before I finally got through. Once I did the service was great but it was very frustrating being cut off so many times.
#
# Sample 25: Tryed to get a phone
#
# Sample 26: Because I've always had a good relationship with company,until I came across unhelpful customer service employee the rest is history.
#
# Sample 27: Great price - very competitive
#
# Sample 28: The customer service for a new customer was excellent.
#
# Sample 29: The customer service is Excellent from when i was a customer, thats why i left but now i'm crawling back haha
#
# Sample 30: Easy setup call handler was very helpful
#
# Sample 31: Engineers helpful with someone not familiar with technology
#
# Sample 32: Perfect
#
# Sample 33: Initial sale was great. Employee was knowledgeable and explained the process and benefits. I had trouble setting up the device when I received it, and the support staff were extremely helpful and got me up and running. The perfect experience!!!
#
# Sample 34: Hi yes when I phoned up the lady I spoke to said she would phone me back but she didn¬"t so after much thought I decided to Canceled the package I Hope this answers your question.?
#
# Sample 35: On the 13th March I ordered with Supanet, I contacted them again on the 3rd April to found out when I could expect my broadband, they had no answers, I immediately cancelled the order and contacted company sales, I spoke with a very helpful gentleman who informed me company would have me up and running in 2 days the 5th April, I immediately confirmed my order. Today is Wednesday 5th April I have received my parcel from company and my broadband is all connected, well done company, excellent service
#
# Sample 36: Reasonable price
#
# Sample 37: A good range of products at affordable prices
#
# Sample 38: Na
#
# Sample 39: Quick, efficient service with easy set up.
#
# Sample 40: Good service at a reasonable price
#
# Sample 41: Very helpful
#
# Sample 42: Good value reasonable prices
#
# Sample 43: The customer service is on point and the offer I was given is excellent.
#
# Sample 44: Very polite and well knew his job inside and out
#
# Sample 45: Agent was very helpful from start to finish and made sure we got the right package for us at the best price.
#
# Sample 46: Friendly and efficient help
#
# Sample 47: I moved into a property last June and was unable to enjoy the services that company Media provided me at my previous address for over 30 years, due to the previous owner declining the installation as she already had Sky installed. I can only assume that she was not sure how the cable would be run as the property is not directly on the kerb line and had its own drive with the house being set back. I did ask if the service was available before I move and was advised it was not at that time, but was advised that company Media were always expanding their services and I should enquire again in the new year. I enquired again in early May and the Sales operative was extremely helpful and was able to call me back and advise me that she would book a site visit to carry out a survey and was hopeful that I would get the service that I had been missing for the past 10 months. The engineers called and we discussed the route and since then things have been moving along swiftly. Termination box at the end of the property access installed last week, civils works and the running of cable yesterday, and full install into property due next Monday. What's Not to like about that. At all times I have been met with a Positive Can Do attitude and a degree of curtesy that I have found to be lacking from other companies over recent years. WELL DONE company MEDIA.
#
# Sample 48: The man we talked to was very help full
#
# Sample 49: Very efficient and friendly
#
# Sample 50: Excellent service
#
# Sample 51: Sade was extremely friendly and helpful
#
# Sample 52: Lied to me, telling me company was already in my home and they could set me up in five days to find out there¬"s no cables anywhere near my home and they¬"ve have to dig up an entire shared drive for me to have company. Very disappointed. I will be cancelling.
#
# Sample 53: Good friendly service quick and easy
#
# Sample 54: Great job, lovely team
#
# Sample 55: On the phone was a helpful fella all my questions and got me up and running in very little time and better internet around my area
#
# Sample 56: Customer service was excellent
#
# Sample 57: Staff is very nice and patient for assisting me to choose the plan.
#
# Sample 58: Communications terrible
#
# Sample 59: Affordable price and broadband speed
#
# Sample 60: Great service over the phone brilliant package which my previous provider that I had been with for 8y could not even match all round very satisfied
#
# Sample 61: Your customer service is awful and you really need to ditch the overseas call centers. Kindness and understanding in the voice go a long way. You can feel the contempt in operator voices (sniggering and laughing when you say you cannot understnd what they are saying - feels intentional) and cannot quite get all of the words due to very strong accents. Your only saving grace is the physical connection and stability of that. Thankfully, because connection quality is good I rarely (if ever - Thank Goodness) have to contact your call centers. Would not touch with a barge pole otherwise. Take a look at Now Broadband whos operators are absolutely marvellous. Lessons learned or brushed under the carpet? Haha
#
# Sample 62: I have been blitzed with over 12 calls from company media in a week. When I ring back; one time my account could not be found. Each time I call, nobody can find a log of who called or the reason for my call. I¬"m not impressed. If it continues I will possibly cancel my order. Enough is enough
#
# Sample 63: The technician was excellent
#
# Sample 64: My internet isn¬"t working your team are pushy and despite having put in account details to talk to someone on the phone you have to repeat them. It¬"s a frustrating and soul destroying experience
#
# Sample 65: Very prompt response
#
# Sample 66: Prompt service
#
# Sample 67: When I finally was able to speak to someone. They were very helpful. Going forward I would suggest it would be helpful to have a phone number, more easily accessible. I came very close to giving up with the online signing.
#
# Sample 68: The work we have had done so far has been done to a high standard. Both the phone agent and the people who came to our house were very professional and polite. Would definitely recommend.
#
# Sample 69: Good customer service. Adam was knowledgeable, helpful and swift in processing the order. The order itself arrived the next day !!!, Amazing and was seamlessly installed and is up and running nicely making a huge difference to the internet speed. Thank you for the great service and hope this is maintained at this level throughout our engaggement.
#
# Sample 70: Very fast Internet

# %% [markdown]
# #### Step 1 - Addressing rule-based corrections

# %%
import re

def fix_encoding_issues(text):
    # Check if text is NaN or None first
    if pd.isna(text) or text is None:
        return None
    
    # Fix common encoding problems
    text = text.replace('¬"', "'")  # Samples 14, 15, 34, 52, 62, 64, 67
    text = text.replace('Ã¡', 'a')
    text = text.replace('Ã©', 'e')
    return text

def handle_incomplete_responses(text):
    # Check if text is NaN or None first
    if pd.isna(text) or text is None:
        return None
    
    # Handle very short non-informative responses
    short_responses = ['Na', 'na', 'N/A', 'n/a', 'NA', 'n.a.', 'N.A.', 'None', 'none', 'No comment', 'no comment']
    if text.strip() in short_responses:
        return None  # Replace with None for missing data 
    return text

def handle_very_short_responses(text):
    # Check if text is NaN or None first
    if pd.isna(text) or text is None:
        return None
    
    # Handle very short responses that are not informative
    if len(text.strip()) < 3:  # Adjust threshold as needed
        return None  # Use None for missing object data
    return text

def normalize_spacing(text):
    # Check if text is NaN or None first
    if pd.isna(text) or text is None:
        return None
    
    # Handle excessive punctuation/spacing
    text = re.sub(r'=+', ' ', text)  # Sample 7: "efficient====="
    text = re.sub(r'\s+', ' ', text)  # Multiple spaces
    text = text.strip()
    return text

def preprocess_telecom_feedback(text):
    # Check if text is NaN or None first
    if pd.isna(text) or text is None:
        return None
    
    # Convert to string if it's not already (handles edge cases)
    text = str(text)
    
    # Apply all preprocessing steps
    text = fix_encoding_issues(text)
    if text is None:
        return None
        
    text = handle_incomplete_responses(text)
    if text is None:
        return None
        
    text = handle_very_short_responses(text)
    if text is None:
        return None
        
    text = normalize_spacing(text)
    
    return text

# %%
# Apply the functions to the DataFrame
df['LTR_COMMENT_CLEAN'] = df['LTR_COMMENT'].apply(fix_encoding_issues).apply(handle_incomplete_responses).apply(handle_very_short_responses).apply(normalize_spacing)

# Print our cleaned sample as the same sample from before, but compared to the original sample
for i, comment in enumerate(sample, 1):
    cleaned_comment = df[df['LTR_COMMENT'] == comment]['LTR_COMMENT_CLEAN'].values[0]
    print(f"Original Sample {i}: {comment}\nCleaned Sample {i}: {cleaned_comment}\n")
# Out:
# Original Sample 1: Very hardworking and punctual quits who carried out the work
# Cleaned Sample 1: Very hardworking and punctual quits who carried out the work
#
# Original Sample 2: I got a good offer with company than sky
# Cleaned Sample 2: I got a good offer with company than sky
#
# Original Sample 3: Is a good service but trying to get to talk to a human person is really hhard , the people you use do not use very good english therefore were not easy to communicate with
# Cleaned Sample 3: Is a good service but trying to get to talk to a human person is really hhard , the people you use do not use very good english therefore were not easy to communicate with
#
# Original Sample 4: Very polite and informative
# Cleaned Sample 4: Very polite and informative
#
# Original Sample 5: Cut my Internet off . Asked for router to be sent after 5.00 tracker shows between 10 and 12
# Cleaned Sample 5: Cut my Internet off . Asked for router to be sent after 5.00 tracker shows between 10 and 12
#
# Original Sample 6: The gentleman who dealt us was so helpful and friendly.. he deserves a lot of credit. Very nice man..
# Cleaned Sample 6: The gentleman who dealt us was so helpful and friendly.. he deserves a lot of credit. Very nice man..
#
# Original Sample 7: you are very efficient=====will you be moving sat dish when you install
# Cleaned Sample 7: you are very efficient will you be moving sat dish when you install
#
# Original Sample 8: How easy it was to set up.
# Cleaned Sample 8: How easy it was to set up.
#
# Original Sample 9: Very adaptable and patient/ helpful
# Cleaned Sample 9: Very adaptable and patient/ helpful
#
# Original Sample 10: I've not agreed to any of this yet I'm bombarded with emails that you cannot reply to and setting up direct debits without my knowledge
# Cleaned Sample 10: I've not agreed to any of this yet I'm bombarded with emails that you cannot reply to and setting up direct debits without my knowledge
#
# Original Sample 11: They are efficient
# Cleaned Sample 11: They are efficient
#
# Original Sample 12: Extremely disappointed with your customer service team. I am still awaiting a response from your fraud prevention team and I have waste hours of my time already on a service I have yet to receive.
# Cleaned Sample 12: Extremely disappointed with your customer service team. I am still awaiting a response from your fraud prevention team and I have waste hours of my time already on a service I have yet to receive.
#
# Original Sample 13: Efficient, courteous staff. Good service and prices. Glad to be on board. John.
# Cleaned Sample 13: Efficient, courteous staff. Good service and prices. Glad to be on board. John.
#
# Original Sample 14: Lady was so nice on the phone as I don¬"t know much about Internet
# Cleaned Sample 14: Lady was so nice on the phone as I don't know much about Internet
#
# Original Sample 15: Good customer service very polite &helpful lad didn¬"t over sell anything. The price was good.
# Cleaned Sample 15: Good customer service very polite &helpful lad didn't over sell anything. The price was good.
#
# Original Sample 16: they where nice and pleasent aswell
# Cleaned Sample 16: they where nice and pleasent aswell
#
# Original Sample 17: The engineer that attended my house was very friendly with great sense of humour
# Cleaned Sample 17: The engineer that attended my house was very friendly with great sense of humour
#
# Original Sample 18: indian call centres
# Cleaned Sample 18: indian call centres
#
# Original Sample 19: Daughters organised my means of communication at distance for my return to live to England. They used you. All went smoothly and quickly.
# Cleaned Sample 19: Daughters organised my means of communication at distance for my return to live to England. They used you. All went smoothly and quickly.
#
# Original Sample 20: Price of my bundle went up 2 days after i placed the order
# Cleaned Sample 20: Price of my bundle went up 2 days after i placed the order
#
# Original Sample 21: Technician was nice
# Cleaned Sample 21: Technician was nice
#
# Original Sample 22: Very helpful
# Cleaned Sample 22: Very helpful
#
# Original Sample 23: I was offered the best option that suits me, friendly conversation, and helpful.
# Cleaned Sample 23: I was offered the best option that suits me, friendly conversation, and helpful.
#
# Original Sample 24: I was cut off 3 times before I finally got through. Once I did the service was great but it was very frustrating being cut off so many times.
# Cleaned Sample 24: I was cut off 3 times before I finally got through. Once I did the service was great but it was very frustrating being cut off so many times.
#
# Original Sample 25: Tryed to get a phone
# Cleaned Sample 25: Tryed to get a phone
#
# Original Sample 26: Because I've always had a good relationship with company,until I came across unhelpful customer service employee the rest is history.
# Cleaned Sample 26: Because I've always had a good relationship with company,until I came across unhelpful customer service employee the rest is history.
#
# Original Sample 27: Great price - very competitive
# Cleaned Sample 27: Great price - very competitive
#
# Original Sample 28: The customer service for a new customer was excellent.
# Cleaned Sample 28: The customer service for a new customer was excellent.
#
# Original Sample 29: The customer service is Excellent from when i was a customer, thats why i left but now i'm crawling back haha
# Cleaned Sample 29: The customer service is Excellent from when i was a customer, thats why i left but now i'm crawling back haha
#
# Original Sample 30: Easy setup call handler was very helpful
# Cleaned Sample 30: Easy setup call handler was very helpful
#
# Original Sample 31: Engineers helpful with someone not familiar with technology
# Cleaned Sample 31: Engineers helpful with someone not familiar with technology
#
# Original Sample 32: Perfect
# Cleaned Sample 32: Perfect
#
# Original Sample 33: Initial sale was great. Employee was knowledgeable and explained the process and benefits. I had trouble setting up the device when I received it, and the support staff were extremely helpful and got me up and running. The perfect experience!!!
# Cleaned Sample 33: Initial sale was great. Employee was knowledgeable and explained the process and benefits. I had trouble setting up the device when I received it, and the support staff were extremely helpful and got me up and running. The perfect experience!!!
#
# Original Sample 34: Hi yes when I phoned up the lady I spoke to said she would phone me back but she didn¬"t so after much thought I decided to Canceled the package I Hope this answers your question.?
# Cleaned Sample 34: Hi yes when I phoned up the lady I spoke to said she would phone me back but she didn't so after much thought I decided to Canceled the package I Hope this answers your question.?
#
# Original Sample 35: On the 13th March I ordered with Supanet, I contacted them again on the 3rd April to found out when I could expect my broadband, they had no answers, I immediately cancelled the order and contacted company sales, I spoke with a very helpful gentleman who informed me company would have me up and running in 2 days the 5th April, I immediately confirmed my order. Today is Wednesday 5th April I have received my parcel from company and my broadband is all connected, well done company, excellent service
# Cleaned Sample 35: On the 13th March I ordered with Supanet, I contacted them again on the 3rd April to found out when I could expect my broadband, they had no answers, I immediately cancelled the order and contacted company sales, I spoke with a very helpful gentleman who informed me company would have me up and running in 2 days the 5th April, I immediately confirmed my order. Today is Wednesday 5th April I have received my parcel from company and my broadband is all connected, well done company, excellent service
#
# Original Sample 36: Reasonable price
# Cleaned Sample 36: Reasonable price
#
# Original Sample 37: A good range of products at affordable prices
# Cleaned Sample 37: A good range of products at affordable prices
#
# Original Sample 38: Na
# Cleaned Sample 38: None
#
# Original Sample 39: Quick, efficient service with easy set up.
# Cleaned Sample 39: Quick, efficient service with easy set up.
#
# Original Sample 40: Good service at a reasonable price
# Cleaned Sample 40: Good service at a reasonable price
#
# Original Sample 41: Very helpful
# Cleaned Sample 41: Very helpful
#
# Original Sample 42: Good value reasonable prices
# Cleaned Sample 42: Good value reasonable prices
#
# Original Sample 43: The customer service is on point and the offer I was given is excellent.
# Cleaned Sample 43: The customer service is on point and the offer I was given is excellent.
#
# Original Sample 44: Very polite and well knew his job inside and out
# Cleaned Sample 44: Very polite and well knew his job inside and out
#
# Original Sample 45: Agent was very helpful from start to finish and made sure we got the right package for us at the best price.
# Cleaned Sample 45: Agent was very helpful from start to finish and made sure we got the right package for us at the best price.
#
# Original Sample 46: Friendly and efficient help
# Cleaned Sample 46: Friendly and efficient help
#
# Original Sample 47: I moved into a property last June and was unable to enjoy the services that company Media provided me at my previous address for over 30 years, due to the previous owner declining the installation as she already had Sky installed. I can only assume that she was not sure how the cable would be run as the property is not directly on the kerb line and had its own drive with the house being set back. I did ask if the service was available before I move and was advised it was not at that time, but was advised that company Media were always expanding their services and I should enquire again in the new year. I enquired again in early May and the Sales operative was extremely helpful and was able to call me back and advise me that she would book a site visit to carry out a survey and was hopeful that I would get the service that I had been missing for the past 10 months. The engineers called and we discussed the route and since then things have been moving along swiftly. Termination box at the end of the property access installed last week, civils works and the running of cable yesterday, and full install into property due next Monday. What's Not to like about that. At all times I have been met with a Positive Can Do attitude and a degree of curtesy that I have found to be lacking from other companies over recent years. WELL DONE company MEDIA.
# Cleaned Sample 47: I moved into a property last June and was unable to enjoy the services that company Media provided me at my previous address for over 30 years, due to the previous owner declining the installation as she already had Sky installed. I can only assume that she was not sure how the cable would be run as the property is not directly on the kerb line and had its own drive with the house being set back. I did ask if the service was available before I move and was advised it was not at that time, but was advised that company Media were always expanding their services and I should enquire again in the new year. I enquired again in early May and the Sales operative was extremely helpful and was able to call me back and advise me that she would book a site visit to carry out a survey and was hopeful that I would get the service that I had been missing for the past 10 months. The engineers called and we discussed the route and since then things have been moving along swiftly. Termination box at the end of the property access installed last week, civils works and the running of cable yesterday, and full install into property due next Monday. What's Not to like about that. At all times I have been met with a Positive Can Do attitude and a degree of curtesy that I have found to be lacking from other companies over recent years. WELL DONE company MEDIA.
#
# Original Sample 48: The man we talked to was very help full
# Cleaned Sample 48: The man we talked to was very help full
#
# Original Sample 49: Very efficient and friendly
# Cleaned Sample 49: Very efficient and friendly
#
# Original Sample 50: Excellent service
# Cleaned Sample 50: Excellent service
#
# Original Sample 51: Sade was extremely friendly and helpful
# Cleaned Sample 51: Sade was extremely friendly and helpful
#
# Original Sample 52: Lied to me, telling me company was already in my home and they could set me up in five days to find out there¬"s no cables anywhere near my home and they¬"ve have to dig up an entire shared drive for me to have company. Very disappointed. I will be cancelling.
# Cleaned Sample 52: Lied to me, telling me company was already in my home and they could set me up in five days to find out there's no cables anywhere near my home and they've have to dig up an entire shared drive for me to have company. Very disappointed. I will be cancelling.
#
# Original Sample 53: Good friendly service quick and easy
# Cleaned Sample 53: Good friendly service quick and easy
#
# Original Sample 54: Great job, lovely team
# Cleaned Sample 54: Great job, lovely team
#
# Original Sample 55: On the phone was a helpful fella all my questions and got me up and running in very little time and better internet around my area
# Cleaned Sample 55: On the phone was a helpful fella all my questions and got me up and running in very little time and better internet around my area
#
# Original Sample 56: Customer service was excellent
# Cleaned Sample 56: Customer service was excellent
#
# Original Sample 57: Staff is very nice and patient for assisting me to choose the plan.
# Cleaned Sample 57: Staff is very nice and patient for assisting me to choose the plan.
#
# Original Sample 58: Communications terrible
# Cleaned Sample 58: Communications terrible
#
# Original Sample 59: Affordable price and broadband speed
# Cleaned Sample 59: Affordable price and broadband speed
#
# Original Sample 60: Great service over the phone brilliant package which my previous provider that I had been with for 8y could not even match all round very satisfied
# Cleaned Sample 60: Great service over the phone brilliant package which my previous provider that I had been with for 8y could not even match all round very satisfied
#
# Original Sample 61: Your customer service is awful and you really need to ditch the overseas call centers. Kindness and understanding in the voice go a long way. You can feel the contempt in operator voices (sniggering and laughing when you say you cannot understnd what they are saying - feels intentional) and cannot quite get all of the words due to very strong accents. Your only saving grace is the physical connection and stability of that. Thankfully, because connection quality is good I rarely (if ever - Thank Goodness) have to contact your call centers. Would not touch with a barge pole otherwise. Take a look at Now Broadband whos operators are absolutely marvellous. Lessons learned or brushed under the carpet? Haha
# Cleaned Sample 61: Your customer service is awful and you really need to ditch the overseas call centers. Kindness and understanding in the voice go a long way. You can feel the contempt in operator voices (sniggering and laughing when you say you cannot understnd what they are saying - feels intentional) and cannot quite get all of the words due to very strong accents. Your only saving grace is the physical connection and stability of that. Thankfully, because connection quality is good I rarely (if ever - Thank Goodness) have to contact your call centers. Would not touch with a barge pole otherwise. Take a look at Now Broadband whos operators are absolutely marvellous. Lessons learned or brushed under the carpet? Haha
#
# Original Sample 62: I have been blitzed with over 12 calls from company media in a week. When I ring back; one time my account could not be found. Each time I call, nobody can find a log of who called or the reason for my call. I¬"m not impressed. If it continues I will possibly cancel my order. Enough is enough
# Cleaned Sample 62: I have been blitzed with over 12 calls from company media in a week. When I ring back; one time my account could not be found. Each time I call, nobody can find a log of who called or the reason for my call. I'm not impressed. If it continues I will possibly cancel my order. Enough is enough
#
# Original Sample 63: The technician was excellent
# Cleaned Sample 63: The technician was excellent
#
# Original Sample 64: My internet isn¬"t working your team are pushy and despite having put in account details to talk to someone on the phone you have to repeat them. It¬"s a frustrating and soul destroying experience
# Cleaned Sample 64: My internet isn't working your team are pushy and despite having put in account details to talk to someone on the phone you have to repeat them. It's a frustrating and soul destroying experience
#
# Original Sample 65: Very prompt response
# Cleaned Sample 65: Very prompt response
#
# Original Sample 66: Prompt service
# Cleaned Sample 66: Prompt service
#
# Original Sample 67: When I finally was able to speak to someone. They were very helpful. Going forward I would suggest it would be helpful to have a phone number, more easily accessible. I came very close to giving up with the online signing.
# Cleaned Sample 67: When I finally was able to speak to someone. They were very helpful. Going forward I would suggest it would be helpful to have a phone number, more easily accessible. I came very close to giving up with the online signing.
#
# Original Sample 68: The work we have had done so far has been done to a high standard. Both the phone agent and the people who came to our house were very professional and polite. Would definitely recommend.
# Cleaned Sample 68: The work we have had done so far has been done to a high standard. Both the phone agent and the people who came to our house were very professional and polite. Would definitely recommend.
#
# Original Sample 69: Good customer service. Adam was knowledgeable, helpful and swift in processing the order. The order itself arrived the next day !!!, Amazing and was seamlessly installed and is up and running nicely making a huge difference to the internet speed. Thank you for the great service and hope this is maintained at this level throughout our engaggement.
# Cleaned Sample 69: Good customer service. Adam was knowledgeable, helpful and swift in processing the order. The order itself arrived the next day !!!, Amazing and was seamlessly installed and is up and running nicely making a huge difference to the internet speed. Thank you for the great service and hope this is maintained at this level throughout our engaggement.
#
# Original Sample 70: Very fast Internet
# Cleaned Sample 70: Very fast Internet

# %% [markdown]
# #### Step 2: Using an spell-checker to correct typos
#
# Tried correcting typos via both local LLM (Deepseek-r1) and using pyspellchecker. Both introduced further errors and either miscorrected certain words or would randomly add non-useful strings of text.
#
# The gains from correcting typos not worth the time investment so we'll proceed with them still in the data. We'll choose models robust to typos in topic modelling and sentiment analysis.

# %%
# Save our adjusted data
df.to_pickle('../data/processed/cleaned_call_script_data.pkl')
df.to_csv('../data/processed/cleaned_call_script_data.csv', index=False)
